# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("../data/main/main.csv")
y = data["Solar Radiation"]   #target column i.e price range
X = data.drop(columns=["Solar Radiation"])

model = DecisionTreeRegressor()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.plot(kind='barh')
plt.show()
# Out:
# [0.13594641 0.         0.00064268 0.0650225  0.01303387 0.49525893
#  0.11367314 0.03021078 0.01784206 0.01629299 0.02896188 0.03430541
#  0.01861518 0.00537238 0.00454343 0.01025205 0.00472417 0.00530214]

# %%
X.head()
# Out:
#    index  INDEX  YEAR  MN  DT  Sunshine hour  MAX Temp  MIN Temp  EVP  \
# 0      0  42483  2016   1   1            6.0      14.2       7.9  0.5
# 1      1  42483  2016   1   2            6.9      16.7       7.3  0.7
# 2      3  42483  2016   1   4            4.7      22.2       8.6  0.7
# 3      4  42483  2016   1   5            5.1      14.8       9.6  0.9
# 4      5  42483  2016   1   6            3.5      17.8      11.1  0.9
#
#    station level pressure  mean sea LP  .RH  Vapour press  wind dir  \
# 0                  1001.7       1011.7   74          14.1        25
# 1                  1004.8       1014.2   73          13.3        32
# 2                  1005.1       1015.4   81          11.0        29
# 3                  1003.6       1013.7   73          11.7        25
# 4                  1006.3       1016.5   79          11.5         0
#
#    wind speed   PM2.5    PM10    NO2
# 0           8  390.02  547.19  43.56
# 1           6  385.68  504.75  43.52
# 2           6  383.25  472.38  42.92
# 3           4  464.24  646.14  47.08
# 4           0  491.62  778.56  44.09

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
